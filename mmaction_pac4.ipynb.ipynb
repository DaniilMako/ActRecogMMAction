# %%
# !pip install -U openmim
# !mim install mmengine
# !mim install mmcv
# !mim install mmdet
# !mim install mmpose
# Out:
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 16.9 MB/s eta 0:00:00
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# ...
#   Using cached https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/mmcv-2.1.0-cp310-cp310-manylinux1_x86_64.whl (94.1 MB)
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 16.4 MB/s eta 0:00:00
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !git clone https://github.com/open-mmlab/mmaction2.git
# !git clone https://github.com/DaniilMako/ActRecogMMAction.git
# %cd mmaction2
# !pip install -v -e .
# Out:
# Cloning into 'mmaction2'...
# remote: Enumerating objects: 22864, done.
# remote: Total 22864 (delta 0), reused 0 (delta 0), pack-reused 22864
# Receiving objects: 100% (22864/22864), 69.62 MiB | 30.19 MiB/s, done.
# Resolving deltas: 100% (16120/16120), done.
# Cloning into 'ActRecogMMAction'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 143 (delta 1), reused 65 (delta 0), pack-reused 72
# Receiving objects: 100% (143/143), 585.28 MiB | 40.88 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Updating files: 100% (103/103), done.
# /content/mmaction2
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Obtaining file:///content/mmaction2
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-4410xa1w/mmaction2.egg-info
# ...

# %%
# распаковка датасета
# !ls
# !unzip data.zip
# Out:
# CITATION.cff	   demo     MANIFEST.in		projects	 requirements.txt  tests
# configs		   docker   mmaction		README.md	 resources	   tools
# data		   docs     mmaction2.egg-info	README_zh-CN.md  setup.cfg
# dataset-index.yml  LICENSE  model-index.yml	requirements	 setup.py

# %%
# начало обучения
# !ls
# !python tools/visualizations/browse_dataset.py \
    configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    browse_out --mode pipeline
# Out:
# CITATION.cff	   demo     MANIFEST.in		projects	 requirements.txt  tests
# configs		   docker   mmaction		README.md	 resources	   tools
# data		   docs     mmaction2.egg-info	README_zh-CN.md  setup.cfg
# dataset-index.yml  LICENSE  model-index.yml	requirements	 setup.py
# [                                                  ] 0/74, elapsed: 0s, ETA:03/05 09:28:53 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 03/05 09:28:53 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ...

# %%
# !pip install timm
# !python tools/visualizations/vis_scheduler.py \
    configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 15.9 MB/s eta 0:00:00
# ...
# Param_scheduler :
# [
#   {
#     "type": "MultiStepLR",
#     "begin": 0,
#     "end": 10,
#     "by_epoch": true,
#     "milestones": [
#       4,
#       8
#     ],
#     "gamma": 0.1
#   }
# ]
#
# Dataset infos:
#  - Dataset size: 4
#  - Batch size per GPU: 4
#  - Number of GPUs: 1
#  - Total batch size: 4
#
# 03/05 09:34:39 - mmengine - WARNING - Dataset range has no metainfo. ``dataset_meta`` in visualizer will be None.
# /usr/local/lib/python3.10/dist-packages/mmengine/optim/scheduler/param_scheduler.py:198:
# ...
# later, you should call them in the opposite order: `optimizer.step()` before `scheduler.step()`.
# Failure to do this will result in PyTorch skipping the first value of the parameter value schedule.
# See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 iters
# Figure(1200x700)

# %%
# !python tools/train.py configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py
# Out:
# 03/05 09:45:16 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 134198205
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
# ...

# %%
# !python tools/test.py configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    work_dirs/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb/best_acc_top1_epoch_1.pth
# Out:
# 03/05 09:57:52 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 783999533
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
# ...

# %%
# !mim download mmaction2 --config tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb --dest .

# %%
# testing
# !python demo/demo.py configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    work_dirs/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb/epoch_10.pth \
    data/kinetics400_tiny/test/typing38.mp4 tools/data/kinetics/label_map_k400.txt

# !python demo/demo.py configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    work_dirs/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb/epoch_10.pth \
    data/kinetics400_tiny/test/doing_exercises38.mp4 tools/data/kinetics/label_map_k400.txt
# Out:
# Loads checkpoint by local backend from path: work_dirs/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb/epoch_10.pth
# 03/05 10:26:34 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 03/05 10:26:34 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# The top-5 labels with corresponding scores are:
# typing:  0.7041938900947571
# doing exercises:  0.2958061695098877
# Loads checkpoint by local backend from path: work_dirs/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb/epoch_10.pth
# 03/05 10:26:45 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# ...
